# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
import folium
from folium import Popup

# %%
sewage = pd.read_csv('SewageLeaksRefined.csv')
colours = ['gray','blue', 'green', 'orange', 'red', 'darkred']
def assign_colour(days):
    if days >= 200:
        return colours[5]
    elif days >= 100:
        return colours[4]
    elif days >= 75:
        return colours[3]
    elif days >= 50:
        return colours[2]
    elif days >= 25:
        return colours[1]
    else:
        return colours[0]

lobitos = folium.Map(location=[-4.457310481797269, -81.2811891931266], zoom_start=17)
# Add bubbles for each sewage pool
for _, row in sewage.iterrows():
    # Scale the radius based on duration (adjust multiplier as needed)
    radius = np.sqrt(row['Duration']) * 0.4

    tooltip_text = f"""
    <b>{row['Name']}</b><br>
    Noted Date: {row['Noted']}<br>
    Resolved Date: {row['Resolved']}<br>
    Duration (Days): {row['Duration']}
    """

    # Add circle marker
    folium.CircleMarker(
        location=[row['Lat'], row['Lon']],
        radius=radius,
        color=assign_colour(row['Duration']),
        fill=True,
        fill_color=assign_colour(row['Duration']),
        fill_opacity=0.6,
        opacity=0.6,
        tooltip=tooltip_text
    ).add_to(lobitos)
lobitos
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e263ecaf2833620a5196a3ff7b40ef9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e263ecaf2833620a5196a3ff7b40ef9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e263ecaf2833620a5196a3ff7b40ef9f = L.map(
#                 &quot;map_e263ecaf2833620a5196a3ff7b40ef9f&quot;,
#                 {
#                     center: [-4.457310481797269, -81.2811891931266],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f4c4b0b64b2a6d83b526e4766c640f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5f4c4b0b64b2a6d83b526e4766c640f3.addTo(map_e263ecaf2833620a5196a3ff7b40ef9f);
#
#
#             var circle_marker_254ea5e3052a5925a4a53887cbad6845 = L.circleMarker(
#                 [-4.454174738, -81.28656553],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 3.8157568056677826, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e263ecaf2833620a5196a3ff7b40ef9f);
#
#
#             circle_marker_254ea5e3052a5925a4a53887cbad6845.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;b&gt;Sewage Pool 1&lt;/b&gt;&lt;br&gt;
#     Noted Date: 01/01/2024&lt;br&gt;
#     Resolved Date: 01/04/2024&lt;br&gt;
#     Duration (Days): 91
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e4f8960f8d6c029af9ae232489cf4678 = L.circleMarker(
#                 [-4.460880675, -81.27643926],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 5.83780780773057, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e263ecaf2833620a5196a3ff7b40ef9f);
#
#
#             circle_marker_e4f8960f8d6c029af9ae232489cf4678.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;b&gt;Sewage Pool 2&lt;/b&gt;&lt;br&gt;
#     Noted Date: 08/04/2024&lt;br&gt;
#     Resolved Date: 07/11/2024&lt;br&gt;
#     Duration (Days): 213
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_d6cad0aa2a5c8ca041df80a2767904dd = L.circleMarker(
#                 [-4.457332831, -81.28650227],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4.732863826479693, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e263ecaf2833620a5196a3ff7b40ef9f);
#
#
#             circle_marker_d6cad0aa2a5c8ca041df80a2767904dd.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;b&gt;Sewage Pool 3&lt;/b&gt;&lt;br&gt;
#     Noted Date: 22/03/2024&lt;br&gt;
#     Resolved Date: 09/08/2024&lt;br&gt;
#     Duration (Days): 140
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9ce40d5a802800c345062d26b231ae23 = L.circleMarker(
#                 [-4.457279933, -81.27866415],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4.732863826479693, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e263ecaf2833620a5196a3ff7b40ef9f);
#
#
#             circle_marker_9ce40d5a802800c345062d26b231ae23.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;b&gt;Sewage Pool 4&lt;/b&gt;&lt;br&gt;
#     Noted Date: 04/05/2024&lt;br&gt;
#     Resolved Date: 21/09/2024&lt;

# %%
selected_yaxis = 'Duration'
limited = sewage.head(50)
fig = plt.figure(figsize=(14, 5))
plt.bar(limited['Name'], limited[selected_yaxis])
plt.ylabel(selected_yaxis)
plt.xticks(rotation=45)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\thoma\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
